# %%
import numpy as np
import pandas as pd
import random
f=pd.read_csv("/home/mt/learn/NGSIM数据处理/csv/80/4:00-4:15/CL_train41.csv")
f1=pd.read_csv("/home/mt/learn/NGSIM数据处理/csv/80/变道邻车信息/merge_RL.csv")
f1
# Out:
#        Vehicle_ID  Frame_ID  Local_X   Local_Y  Preceding  Following  Lane_ID  \
# 0            13.0     937.0   41.776  1452.031       15.0       41.0      4.0
# 1            13.0     938.0   41.772  1454.013       15.0       41.0      4.0
# 2            13.0     939.0   41.766  1456.007       15.0       41.0      4.0
# 3            13.0     940.0   41.761  1458.059       15.0       41.0      4.0
# 4            13.0     941.0   41.726  1460.187       15.0       41.0      4.0
# 5            13.0     942.0   41.802  1462.349       15.0       41.0      4.0
# 6            13.0     943.0   41.900  1464.476       15.0       41.0      4.0
# 7            13.0     944.0   42.082  1466.567       15.0       41.0      4.0
# 8            13.0     945.0   42.172  1468.691       15.0       41.0      4.0
# 9            13.0     946.0   42.227  1470.900       15.0       41.0      4.0
# 10           13.0     947.0   42.274  1473.158       15.0       41.0      4.0
# ...

# %%
def repeat(re_list):
    a=[]
    for i in re_list:
        if i not in a:
            a.append(i)
    return a

# %%
ID=f1.Vehicle_ID.values
ID=repeat(ID)
# Out:
# 252

# %%
f=f[f.Vehicle_ID.isin(ID)]
f
# Out:
#        Vehicle_ID  Frame_ID  Total_Frames    Global_Time  Local_X   Local_Y  \
# 0              13       937           948  1113433228600   41.776  1452.031
# 1              13       938           948  1113433228700   41.772  1454.013
# 2              13       939           948  1113433228800   41.766  1456.007
# 3              13       940           948  1113433228900   41.761  1458.059
# 4              13       941           948  1113433229000   41.726  1460.187
# 5              13       942           948  1113433229100   41.802  1462.349
# 6              13       943           948  1113433229200   41.900  1464.476
# 7              13       944           948  1113433229300   42.082  1466.567
# 8              13       945           948  1113433229400   42.172  1468.691
# 9              13       946           948  1113433229500   42.227  1470.900
# 10             13       947           948  1113433229600   42.274  1473.158
# ...
