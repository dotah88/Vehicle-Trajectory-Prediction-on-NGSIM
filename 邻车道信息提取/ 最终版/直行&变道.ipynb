# %%
import numpy as np
import pandas as pd
f1=pd.read_csv("/home/mt/learn/NGSIM数据处理/csv/101/7:50-8:05/new/v1-y4_new.csv")
f2=pd.read_csv("/home/mt/learn/NGSIM数据处理/csv/101/8:05-8:20/new/v1-y4_new.csv")
# f3=pd.read_csv("/home/mt/learn/NGSIM数据处理/csv/80/5:15-5:30/new/v1-y4.csv")
# f4=pd.read_csv("/home/mt/learn/NGSIM数据处理/csv/101/7:50-8:05/new/v1-y4.csv")
# f5=pd.read_csv("/home/mt/learn/NGSIM数据处理/csv/101/8:05-8:20/new/v1-y4.csv")

# %%
f6=pd.concat([f1,f2],ignore_index=True)
f6=f6[['Vehicle_ID','Frame_ID','v1','v2','v3','v4','y1','y2','y3','y4','label']]
f6.to_csv('/home/mt/learn/NGSIM数据处理/csv/合并数据/v1-y4_750-820.csv',index=0)
f6
# Out:
#       Vehicle_ID  Frame_ID     v1     v2     v3     v4       y1       y2  \
# 0              8        97   0.82   3.39  40.00   8.29   64.103  -80.902
# 1             10       384  -7.51   0.00  10.84   9.02  105.303  -62.597
# 2             12       381  -3.50  -3.63  10.12   8.16   62.190  -72.931
# 3             13       192  -4.99   0.13   7.37   6.78   83.977  -63.849
# 4             20       295   0.15  -9.20   4.96   4.85  123.540 -199.923
# 5             21       351  -2.58   3.89   2.58   6.40   80.371 -119.794
# 6             23       390  -7.10  -9.77  14.77  16.14   72.548  -96.063
# 7             25       170   0.47   0.17   5.25  -1.26   93.173  -52.291
# 8             26       247  -1.19   4.35   5.43   0.65   58.409  -51.634
# 9             27       346  -4.90   2.92  10.00   0.00   89.131  -51.282
# 10            32       334   1.64   6.30 -10.02 -10.02   78.209  -67.154
# 11            34       324   0.91  -0.59  14.90   1.56   75.021 -107.195
# ...
